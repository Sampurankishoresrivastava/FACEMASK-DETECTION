# %%
#                                    MAJOR PROJECT ON FACEMASK DETECTION
#   Tasks:
#       1.Build a Neural Network, to classify “Mask” and “Without Mask” images.
#       2.Using OpenCV, predict each image in a webcam video( whether it belongs to “Mask” or “Without Mask” image).  Round a rectangle on the detected face, and also put a text above that rectangle, depicting whether it is a masked
#         or a non-masked image.   
#  SUBMITTED BY:-Sampuran Kishore Srivastava  EMAIL ID:-sampuran01122001@gmail.com

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/archive" -d "/content/drive/MyDrive/archive"
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/archive, /content/drive/MyDrive/archive.zip or /content/drive/MyDrive/archive.ZIP.

# %%
import os
main_dir = '/content/drive/My Drive/archive/New Masks Dataset'
train_dir = os.path.join(main_dir,'Train')
test_dir = os.path.join(main_dir,'Test')
valid_dir = os.path.join(main_dir,'Validation')

train_mask_dir = os.path.join(train_dir,'Mask')
train_nomask_dir = os.path.join(train_dir,'Non Mask')

# %%
print(train_dir)
# Out:
# /content/drive/My Drive/archive/New Masks Dataset/Train

# %%
train_mask_names = os.listdir(train_mask_dir)
print(train_mask_names[:10])

train_nomask_names = os.listdir(train_nomask_dir)
print(train_nomask_names[:10])
# Out:
# ['0003.jpg', '0029.jpg', '0022.jpg', '0019.jpg', '0006.jpg', '0018.jpg', '0040.jpg', '0042.jpg', '0027.jpg', '0037.jpg']
# ['135.jpg', '12.jpg', '107.jpg', '153.jpg', '149.jpg', '127.jpg', '1.jpg', '110.jpg', '154.jpg', '151.jpg']

# %%
#image data generation
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range = 0.2,
                                   rotation_range = 40,
                                   horizontal_flip = True
                                   )
test_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(150,150),
                                                    batch_size = 32,
                                                    class_mode = 'binary'
                                                    )
test_generator = test_datagen.flow_from_directory(test_dir,
                                                    target_size=(150,150),
                                                    batch_size = 32,
                                                    class_mode = 'binary'
                                                    )
valid_generator = validation_datagen.flow_from_directory(valid_dir,
                                                    target_size=(150,150),
                                                    batch_size = 32,
                                                    class_mode = 'binary'
                                                    )
# Out:
# Found 600 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Found 306 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'Mask': 0, 'Non Mask': 1}

# %%
train_generator.image_shape
# Out:
# (150, 150, 3)

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),padding='SAME',activation='relu',input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))


model.add(Conv2D(64,(3,3),padding='SAME',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(256,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 87616)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               22429952
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 22,449,601
# Trainable params: 22,449,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.001),loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
hisory = model.fit(train_generator,
                   epochs = 30,
                   validation_data = valid_generator)
# Out:
# Epoch 1/30
# 19/19 [==============================] - 229s 12s/step - loss: 3.2670 - accuracy: 0.5200 - val_loss: 0.6928 - val_accuracy: 0.4706
# Epoch 2/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.6185 - accuracy: 0.6900 - val_loss: 0.6736 - val_accuracy: 0.7745
# Epoch 3/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.4547 - accuracy: 0.8083 - val_loss: 0.5342 - val_accuracy: 0.8235
# Epoch 4/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.3658 - accuracy: 0.8600 - val_loss: 0.4403 - val_accuracy: 0.8660
# Epoch 5/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2890 - accuracy: 0.9000 - val_loss: 0.3080 - val_accuracy: 0.9052
# Epoch 6/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2783 - accuracy: 0.9000 - val_loss: 0.3433 - val_accuracy: 0.8954
# Epoch 7/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2589 - accuracy: 0.9017 - val_loss: 0.2957 - val_accuracy: 0.9150
# Epoch 8/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2319 - accuracy: 0.9250 - val_loss: 0.3155 - val_accuracy: 0.8987
# Epoch 9/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2398 - accuracy: 0.9083 - val_loss: 0.3651 - val_accuracy: 0.8562
# Epoch 10/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2680 - accuracy: 0.9050 - val_loss: 0.3604 - val_accuracy: 0.8791
# Epoch 11/30
# 19/19 [==============================] - 38s 2s/step - loss: 0.2468 - accuracy: 0.9050 - val_loss: 0.2834 - val_accuracy: 0.9052
# Epoch 12/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2397 - accuracy: 0.9167 - val_loss: 0.2692 - val_accuracy: 0.9085
# Epoch 13/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1924 - accuracy: 0.9267 - val_loss: 0.2448 - val_accuracy: 0.9020
# Epoch 14/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2331 - accuracy: 0.9067 - val_loss: 0.2957 - val_accuracy: 0.8856
# Epoch 15/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2319 - accuracy: 0.9150 - val_loss: 0.2917 - val_accuracy: 0.8987
# Epoch 16/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1949 - accuracy: 0.9283 - val_loss: 0.2699 - val_accuracy: 0.8922
# Epoch 17/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2178 - accuracy: 0.9183 - val_loss: 0.2483 - val_accuracy: 0.9150
# Epoch 18/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1747 - accuracy: 0.9450 - val_loss: 0.2430 - val_accuracy: 0.8987
# Epoch 19/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1842 - accuracy: 0.9300 - val_loss: 0.2277 - val_accuracy: 0.9183
# Epoch 20/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2258 - accuracy: 0.9117 - val_loss: 0.2964 - val_accuracy: 0.8889
# Epoch 21/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1874 - accuracy: 0.9383 - val_loss: 0.2375 - val_accuracy: 0.9085
# Epoch 22/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1749 - accuracy: 0.9217 - val_loss: 0.2255 - val_accuracy: 0.9118
# Epoch 23/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1824 - accuracy: 0.9333 - val_loss: 0.2414 - val_accuracy: 0.9085
# Epoch 24/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1940 - accuracy: 0.9283 - val_loss: 0.2459 - val_accuracy: 0.9085
# Epoch 25/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1669 - accuracy: 0.9417 - val_loss: 0.2487 - val_accuracy: 0.9085
# Epoch 26/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1713 - accuracy: 0.9367 - val_loss: 0.2963 - val_accuracy: 0.8660
# Epoch 27/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.2191 - accuracy: 0.9283 - val_loss: 0.2300 - val_accuracy: 0.9118
# Epoch 28/30
# 19/19 [==============================] - 39s 2s/step - loss: 0.1761 - accuracy: 0.9333 - val_loss: 0.2469 - val_accuracy: 0.9150
# Epoch 29/30
# 19/19 [==============================] - 40s 2s/step - loss: 0.1738 - accuracy: 0.9417 - val_loss: 0.2320 - val_accuracy: 0.9216
# Epoch 30/30
# 19/19 [==============================] - 40s 2s/step - loss: 0.1644 - accuracy: 0.9383 - val_loss: 0.2342 - val_accuracy: 0.9216

# %%
test_loss , test_acc = model.evaluate(test_generator)
print('test acc :{} test loss:{}'.format(test_acc,test_loss))
# Out:
# 4/4 [==============================] - 18s 6s/step - loss: 0.1841 - accuracy: 0.9400
# test acc :0.9399999976158142 test loss:0.18410275876522064

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

fname = files.upload()
print(fname)
f=list(fname.keys())[0]
img_path='/content/'+f
img = image.load_img(img_path , target_size=(150,150))
images = image.img_to_array(img)
images=np.expand_dims(images,axis=0)
prediction = model.predict(images)
if prediction==0:
  print('mask')
else:
  print('nomask')
# Out:
#      <input type="file" id="files-4b2daeb8-494f-48eb-abaa-af82f92f56fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b2daeb8-494f-48eb-abaa-af82f92f56fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.jpg to 2.jpg
# {'2.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x01\xb1\x01@\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfd\xfc\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x03\x83\xf0/\xc7o\x0fx\xfb\xe3?\x8f\xbe\t\xe9\xda=\xe4Z\x8f\x80\x1fL]J\xe2\xe3g\x95t/\xad\xbe\xd1\x1bE\xb4\x96\xc2\xaeU\xb7\x01\xc8\xe3#\x9a\xee\xd0\xe5\x01\xc1\xe9\xdf\xad|\xbd\xf0"\xeb\xec\xbf\xf0T\xff\x00\xda\x17BY%"\x7f\x03x\x1fP \xfd\xd0\xcc\xba\x9c\x1c\x7f\xe0?5\xf5\n\xfd\xd1\xf4\xad+F0\x9aQ\xec\x9f\xde\x93\x14]\xd0\xb4QEf0\xa2\x8a(\x03\x83\xfd\xa3>:\xf8\x7f\xf6q\xf8C\xac|d\xf16\x8f\x7f\xa8X\xe8\xd2Z\x89\xed4\xc5C;\xf9\xd71\xdb\x82\xa1\x99G\r(\'$\x1c+c5\xdd\xa7\xdc\x1fOJ\xf9\xdf\xfe\n\xb9mo\'\xfc\x13\xcf\xe2\xbd\xdd\xcf\xfa\xbb\x0f\r\xfd\xbeO\x9b\x18\x16\xf3Gq\x9f\xfc\x87^\xff\x00\xa1]-\xf6\x89g|\x8f\xb8Mk\x1b\x86\xcer\n\x83\x9a\xe8t\xa2\xb0q\xab\xd5\xcaK\xeeQk\xf3d\xdd\xf3\xd8\xb5E\x14W9AE\x14P\x01\\\x0f\x84\xbe:\xf8{\xc5\x9f\x1e\xbce\xf0\x16\xd7G\xbf\x87R\xf0n\x9b\xa6_^\xdeM\xb3\xc8\xb9\x8e\xf8Lc\xf2\xf0\xc5\xb2\xbeC\x03\xb8\x0e}k\xbe\xaf\x9f>\x1eE\r\x97\xfc\x14\xb7\xe2\x8cb|\xbd\xef\xc2\x9f\n\xceb\xdb\xfd\xdb\xedb2\x7f \xb5\xb5(Fq\x9b}\x15\xff\x00\x14\xbfR$\xdaj\xc7\xd0I\xf7G\xd2\x96\x81\xd0}(\xacK\n(\xa2\x80\n\xe5\xbe.\xfcJ\xd3\xfe\x0f\xfc3\xf1\x07\xc5\r^\xc2\xe2\xf2\xd7\xc3\xfad\xd7\xf7\x16\xb6{|\xd7\x8e5,\xc1w\x10\xb9\xc08\xc9\x1d;\xd7S^u\xfbX[C}\xfb1|G\xb5\xb9\x07cx\x1fU\xce:\xfc\xb6\x92\xb0\xc7\xe5ZQ\x8c%Z*{]_\xd2\xe4\xcd\xb5\x06\xd1\xdeh\xba\x95\xb6\xb1\xa3\xdaj\xf6e\x8c7V\xd1\xcd\x11n\xbbYC\x0c\xfe\x06\xac\xd7\x1b\xfb;\xeb\xe3\xc5\x7f\x00<\x0f\xe2u\xcf\xfcL|\x1f\xa6\\\xfc\xdd\x7fyk\x1b\xf3\xf9\xd7d:sEX{:\xb2\x8ff\xd0\xa9\xc9\xca\t\xbe\xa8(\xa2\x8a\xcc\xb0\xa2\x8a(\x03\x94\xb9\xf8\x9d\xa4\xdb\xfc^\xb7\xf8@\xfae\xd1\xbc\xb9\xf0\xfc\xfa\xba]\x8d\xbeO\x97\x1d\xc4P2}\xed\xdb\xb7J\xa7\xa61\xde\xba\xa8\xf3\xb1s\xd7\x035\xe4~5\xbc\x1aG\xed\x99\xe0Y\x1b\xa6\xad\xe0\xbdv\xcc\x7f\xbd\x14\xd6S\x0f\xd3uz\xe2\x9c\xa8#\xd2\xb7\xadIB0\x92\xfbQ\xbf\xe2\xd7\xe8eNnR\x92\xec\xff\x00D\xc5\xa2\x8a+\x03P\xa2\x8a(\x02\tX\x87$\xc6O<\x01\xdc\xff\x00\x9e98\xcds\x7f\x08\xbe&i\xdf\x17\xbc\x01a\xe3\xfd+K\xba\xb3\x87Pi\x82Z\xdd\x85\xdf\x13G+\xc4\xc1\xb6\x12>\xf2\x1e\x ...
# nomask

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()
for f in uploaded.keys():
  img_path='/content/'+f
  img = image.load_img(img_path , target_size=(150,150))
  images = image.img_to_array(img)
  images=np.expand_dims(images,axis=0)
  prediction = model.predict(images)
  if prediction==0:
    print('mask')
  else:
    print('nomask')
# Out:
#      <input type="file" id="files-9d52ea2c-9038-42fa-b88a-5c34ee8e56f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d52ea2c-9038-42fa-b88a-5c34ee8e56f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 0003.jpg to 0003.jpg
# mask

# %%
model.save('savemodel.h5')

# %%
import cv2
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img , img_to_array
import numpy as np

model =load_model('model.h5')

img_width , img_height = 150,150

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(0)

img_count_full = 0

font = cv2.FONT_HERSHEY_SIMPLEX
org = (1,1)
class_label = ''
fontScale = 1
color = (255,0,0)
thickness = 2

while True:
    img_count_full += 1
    response , color_img = cap.read()

    if response == False:
        break

    scale = 50
    width = int(color_img.shape[1]*scale /100)
    height = int(color_img.shape[0]*scale/100)
    dim = (width,height)

    color_img = cv2.resize(color_img, dim ,interpolation= cv2.INTER_AREA)

    gray_img = cv2.cvtColor(color_img,cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray_img, 1.1, 6)

    img_count = 0
    for (x,y,w,h) in faces:
        org = (x-10,y-10)
        img_count += 1
        color_face = color_img[y:y+h,x:x+w]
        cv2.imwrite('input/%d%dface.jpg'%(img_count_full,img_count),color_face)
        img = load_img('input/%d%dface.jpg'%(img_count_full,img_count),target_size=(img_width,img_height))
        img = img_to_array(img)
        img = np.expand_dims(img,axis=0)
        prediction = model.predict(img)


        if prediction==0:
            class_label = "Mask"
            color = (255,0,0)

        else:
            class_label = "No Mask"
            color = (0,255,0)


        cv2.rectangle(color_img,(x,y),(x+w,y+h),(0,0,255),3)
        cv2.putText(color_img, class_label, org, font ,fontScale, color, thickness,cv2.LINE_AA)

    cv2.imshow('Face mask detection', color_img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
